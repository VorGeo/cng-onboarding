# %%
import datetime

# %%
print(1+2+3)
print(datetime.datetime.now())
# Out:
# 6
# 2025-04-02 12:57:56.162851

# %%
# Run this out of order

print(datetime.datetime.now())
# Out:
# 2025-04-02 12:57:57.572245
